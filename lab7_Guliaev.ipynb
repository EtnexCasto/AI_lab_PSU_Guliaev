# %% [markdown]
# # Лабораторная работа 7
#
# Тема: **Многослойный персептрон для табличных данных (полный цикл: предобработка → PyTorch → анализ)**
# Цель: на табличном датасете с числовыми и категориальными признаками пройти все этапы: подготовка данных, построение MLP в PyTorch, обучение, оценка и осмысленная интерпретация результатов.
#
# > Этот ноутбук не предназначен для автоматического заполнения текстом из генеративных моделей.
# > Большая часть баллов ставится за то, **как вы сами объясняете** сделанные шаги и комментируете свои эксперименты.
# > Код можно использовать как каркас, но текстовые ответы и выбор настроек должны быть вашими.

# %% [markdown]
# ## 1. Ваше понимание задачи (коротко)
#
# Перед тем как писать код, сформулируйте для себя:
#
# 1. Чем, на ваш взгляд, работа с табличными данными отличается от работы с картинками (MNIST) в предыдущих работах?
# 2. Какие сложности добавляет наличие одновременно числовых и категориальных признаков?
# 3. Зачем в такой задаче может понадобиться нейросеть, если у нас есть логистическая регрессия, деревья решений и т.п.?
#
# Напишите 5–8 предложений **на своём языке**, без попытки выдать энциклопедическое определение.

# %%
intro_text = """ЗДЕСЬ НАПИШИТЕ, КАК ВЫ ПОНИМАЕТЕ РАБОТУ С ТАБЛИЧНЫМИ ДАННЫМИ.
Попробуйте сравнить её с задачами на картинки/тексты и честно описать,
зачем, по-вашему, в таких задачах имеет смысл пробовать MLP.

1. На мой взгляд, в отличие от работы с картинками, работа с табличными данными должна быть гораздо легче, потому что данные изначально не нужно преобразовывать в то, что будет понимать компьютер.
2. Одновременно числовые и категориальные признаки имеют разные типы данных, к каждому нужен отдельный подход в обработке, поэтому с этой точки зрения они добавляют сложности.
3. Я думаю, что нейросеть в такой задаче поможет новичкам разработчикам научиться внедрять ИИ в свои проекты, тем самым облегчив себе работу. Ныне уже большинство переходит на ИИ-разработку, таковы правила игры."""
print(intro_text)

# %% [markdown]
# ## 2. Импорт библиотек и настройка среды
#
# В этом блоке:
# - импортируем базовые библиотеки для работы с табличными данными (`pandas`, `sklearn`),
# - импортируем PyTorch и инструменты для обучения,
# - фиксируем зерно случайности (одно число),
# - определяем устройство (`cpu` / `cuda`).

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt

# Ваш seed (выберите сами и используйте последовательно)
MY_SEED = 0
torch.manual_seed(MY_SEED)
np.random.seed(MY_SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Устройство:", device)
print("MY_SEED =", MY_SEED)
# Out:
# Устройство: cuda
# MY_SEED = 0

# %% [markdown]
# ## 3. Табличные данные: генерация и первичный осмотр
#
# Для этой лабораторной можно брать реальный CSV‑файл, но чтобы не зависеть от внешних данных, здесь используется синтетический пример.
#
# Шаги:
# - сгенерировать датасет с помощью `make_classification` (бинарная классификация);
# - обернуть в `pandas.DataFrame` и добавить одну простую категориальную колонку;
# - посмотреть на первые строки и распределение целевой переменной.

# %%
X, y = make_classification(
    n_samples=8000,
    n_features=8,
    n_informative=5,
    n_redundant=1,
    n_repeated=0,
    n_classes=2,
    random_state=MY_SEED
)

df = pd.DataFrame(X, columns=[f"feat_{i}" for i in range(X.shape[1])])
df["target"] = y

# Простейшая категориальная фича на основе порога по одному из признаков
df["cat_col"] = np.where(df["feat_0"] > 0, "high", "low")

print(df.head())
print("Форма датафрейма:", df.shape)
print("Распределение классов (доля):\n", df["target"].value_counts(normalize=True))
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0  0.062898 -0.444796  1.584039 -1.917563 -1.442824 -0.106344 -0.477764
# 1  2.504537  0.193514  0.826514  0.823705  0.800851 -0.354166 -1.215238
# 2 -0.917150  1.116519  0.824290 -0.036450 -0.088655  0.092435  0.673109
# 3  1.586278 -0.124920 -0.541305  1.389680 -0.990385 -0.392417  0.288695
# 4 -1.002887 -0.691114  0.588268  0.677532 -0.559328 -1.591741 -2.117714
#
#      feat_7  target cat_col
# 0 -1.654157       1    high
# 1 -2.721326       0    high
# 2  0.129188       1     low
# 3  0.443020       0    high
# 4 -1.313416       1     low
# Форма датафрейма: (8000, 10)
# Распределение классов (доля):
#  target
# 1    0.500625
# 0    0.499375
# Name: proportion, dtype: float64

# %% [markdown]
# Отделим списки числовых и категориальных колонок и целевую переменную.
# Это пригодится при предобработке.

# %%
numeric_cols = [c for c in df.columns if c.startswith("feat_")]
cat_cols = ["cat_col"]
target_col = "target"

print("Числовые признаки:", numeric_cols)
print("Категориальные признаки:", cat_cols)
# Out:
# Числовые признаки: ['feat_0', 'feat_1', 'feat_2', 'feat_3', 'feat_4', 'feat_5', 'feat_6', 'feat_7']
# Категориальные признаки: ['cat_col']

# %% [markdown]
# ## 4. Разбиение на train/val/test и предобработка
#
# Мы не хотим использовать тестовую выборку при подборе гиперпараметров, поэтому разделим данные в два этапа:
# - train + временный остаток (val+test);
# - остаток → val + test.
#
# Числовые признаки будем масштабировать (`StandardScaler`), категориальные — кодировать через `OneHotEncoder`.
# Важно: все преобразования обучаются **только на train**, затем применяются к val и test.

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.3,
    random_state=MY_SEED,
    stratify=df[target_col]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=MY_SEED,
    stratify=temp_df[target_col]
)

print("Размер train:", train_df.shape)
print("Размер val  :", val_df.shape)
print("Размер test :", test_df.shape)
# Out:
# Размер train: (5600, 10)
# Размер val  : (1200, 10)
# Размер test : (1200, 10)

# %%
scaler = StandardScaler()
encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")

# обучаем только на train
scaler.fit(train_df[numeric_cols])
encoder.fit(train_df[cat_cols])

def transform_df(df_part):
    X_num = scaler.transform(df_part[numeric_cols])
    X_cat = encoder.transform(df_part[cat_cols])
    X_all = np.hstack([X_num, X_cat])
    y_all = df_part[target_col].values.astype(np.int64)
    return X_all, y_all

X_train, y_train = transform_df(train_df)
X_val, y_val = transform_df(val_df)
X_test, y_test = transform_df(test_df)

print("Форма X_train:", X_train.shape)
print("Форма X_val  :", X_val.shape)
print("Форма X_test :", X_test.shape)
print("Кол-во классов в train:", np.bincount(y_train))
# Out:
# Форма X_train: (5600, 10)
# Форма X_val  : (1200, 10)
# Форма X_test : (1200, 10)
# Кол-во классов в train: [2796 2804]

# %% [markdown]
# ### Ваш короткий комментарий по данным
#
# Здесь полезно в 3–5 предложениях описать:
# - выглядят ли классы примерно сбалансированными;
# - нет ли подозрений на слишком лёгкую/сложную задачу, исходя из числа признаков и информативности;
# - как вы ожидаете, будет вести себя простая линейная модель на этих данных.

# %%
data_comment = """ЗДЕСЬ КРАТКО ОПИШИТЕ ВАШЕ ВПЕЧАТЛЕНИЕ О ДАННЫХ.
Можно упомянуть распределение классов, размерность, интуитивную сложность задачи.

Классы сбалансированы, распределение примерно по 50%.
Возможно, слишком лёгкая задача из-за количества признаков и информативности. Думаю, что на меньшем датасете также можно обучить модель.
На этих данных линейная модель может показать хороший результат, учитывая, что тут бинарное распределение. Однако сложности добавляют категориальные признаки, поэтому предполагаю, что точность такой модели будет не больше 66%."""
print(data_comment)

# %% [markdown]
# ## 5. Dataset и DataLoader для табличных данных
#
# Опишем класс `TabularDataset`, который превращает массивы NumPy в тензоры PyTorch, и создадим `DataLoader` для train/val/test.

# %%
class TabularDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = TabularDataset(X_train, y_train)
val_dataset = TabularDataset(X_val, y_val)
test_dataset = TabularDataset(X_test, y_test)

# выберите batch_size, который вам комфортен (обоснуйте это позже)
batch_size = 256
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("Кол-во батчей в train_loader:", len(train_loader))
# Out:
# Кол-во батчей в train_loader: 22

# %% [markdown]
# ## 6. Архитектура MLP для табличных данных
#
# Теперь опишем саму сеть.
# Требования к базовому варианту:
# - входной размер = число столбцов в `X_train`;
# - 1–2 скрытых слоя с нелинейностью (ReLU или другая на ваш выбор);
# - выходной слой из 2 нейронов (для двух классов), без Softmax.
#
# Параметры (размеры слоёв) выбирайте так, чтобы модель не была ни слишком крошечной, ни чрезмерно большой.

# %%
X_train_col = X_train.shape[1]
input_dim = X_train_col
hidden_dim1 = 64
hidden_dim2 = 32
output_dim = 2

class TabularMLP(nn.Module):
    def __init__(self, in_features, h1, h2, out_features):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features, h1),
            nn.ReLU(),
            # nn.Dropout(0.5),
            nn.Linear(h1, h2),
            nn.ReLU(),
            # nn.Dropout(0.5),
            nn.Linear(h2, out_features)
        )

    def forward(self, x):
        return self.net(x)

model = TabularMLP(input_dim, hidden_dim1, hidden_dim2, output_dim).to(device)
print(model)
# Out:
# TabularMLP(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# Выберите функцию потерь и оптимизатор. Для данной задачи подойдёт:
# - `nn.CrossEntropyLoss` для потерь;
# - любой из стандартных оптимизаторов (`Adam`, `SGD`, `AdamW`...) с осмысленным `learning_rate`.

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = 0.01
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

print("Функция потерь:", criterion)
print("Оптимизатор:", optimizer)
print("learning_rate =", learning_rate)
# Out:
# Функция потерь: CrossEntropyLoss()
# Оптимизатор: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.01
# )
# learning_rate = 0.01

# %% [markdown]
# ## 7. Цикл обучения и валидации
#
# Реализуем стандартные функции:
# - `train_one_epoch` — один проход по train,
# - `evaluate` — расчёт loss и accuracy на val или test.
#
# Затем запустим обучение на несколько эпох, сохраняя историю метрик для визуализации.

# %%
def train_one_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    running_correct = 0
    total = 0

    for X_batch, y_batch in dataloader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        logits = model(X_batch)
        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * X_batch.size(0)
        preds = logits.argmax(dim=1)
        running_correct += (preds == y_batch).sum().item()
        total += X_batch.size(0)

    epoch_loss = running_loss / total
    epoch_acc = running_correct / total
    return epoch_loss, epoch_acc


def evaluate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            logits = model(X_batch)
            loss = criterion(logits, y_batch)

            running_loss += loss.item() * X_batch.size(0)
            preds = logits.argmax(dim=1)
            running_correct += (preds == y_batch).sum().item()
            total += X_batch.size(0)

    epoch_loss = running_loss / total
    epoch_acc = running_correct / total
    return epoch_loss, epoch_acc

print("Функции train_one_epoch и evaluate определены.")
# Out:
# Функции train_one_epoch и evaluate определены.

# %%
num_epochs = 100 # при выполнении работы попробуйте разные числа и сравните

history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": []
}

for epoch in range(1, num_epochs + 1):
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss, val_acc = evaluate(model, val_loader, criterion, device)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    print(f"Эпоха {epoch}/{num_epochs} | "
          f"train_loss={train_loss:.4f}, train_acc={train_acc:.4f}, "
          f"val_loss={val_loss:.4f}, val_acc={val_acc:.4f}")
# Out:
# Эпоха 1/100 | train_loss=0.0096, train_acc=0.9975, val_loss=0.2539, val_acc=0.9708
# Эпоха 2/100 | train_loss=0.0104, train_acc=0.9977, val_loss=0.2381, val_acc=0.9700
# Эпоха 3/100 | train_loss=0.0120, train_acc=0.9966, val_loss=0.2307, val_acc=0.9708
# Эпоха 4/100 | train_loss=0.0137, train_acc=0.9961, val_loss=0.2476, val_acc=0.9683
# Эпоха 5/100 | train_loss=0.0179, train_acc=0.9938, val_loss=0.2585, val_acc=0.9692
# Эпоха 6/100 | train_loss=0.0318, train_acc=0.9893, val_loss=0.2874, val_acc=0.9708
# Эпоха 7/100 | train_loss=0.0466, train_acc=0.9871, val_loss=0.2096, val_acc=0.9708
# Эпоха 8/100 | train_loss=0.0335, train_acc=0.9902, val_loss=0.2238, val_acc=0.9658
# Эпоха 9/100 | train_loss=0.0311, train_acc=0.9909, val_loss=0.2089, val_acc=0.9683
# Эпоха 10/100 | train_loss=0.0339, train_acc=0.9891, val_loss=0.1945, val_acc=0.9708
# Эпоха 11/100 | train_loss=0.0252, train_acc=0.9907, val_loss=0.1968, val_acc=0.9733
# Эпоха 12/100 | train_loss=0.0185, train_acc=0.9957, val_loss=0.2103, val_acc=0.9733
# Эпоха 13/100 | train_loss=0.0114, train_acc=0.9964, val_loss=0.2125, val_acc=0.9767
# Эпоха 14/100 | train_loss=0.0087, train_acc=0.9975, val_loss=0.2083, val_acc=0.9750
# Эпоха 15/100 | train_loss=0.0078, train_acc=0.9980, val_loss=0.2175, val_acc=0.9758
# Эпоха 16/100 | train_loss=0.0064, train_acc=0.9986, val_loss=0.2206, val_acc=0.9742
# Эпоха 17/100 | train_loss=0.0067, train_acc=0.9980, val_loss=0.2233, val_acc=0.9733
# Эпоха 18/100 | train_loss=0.0064, train_acc=0.9984, val_loss=0.2191, val_acc=0.9742
# Эпоха 19/100 | train_loss=0.0066, train_acc=0.9988, val_loss=0.2308, val_acc=0.9758
# Эпоха 20/100 | train_loss=0.0055, train_acc=0.9986, val_loss=0.2304, val_acc=0.9750
# Эпоха 21/100 | train_loss=0.0051, train_acc=0.9989, val_loss=0.2306, val_acc=0.9750
# Эпоха 22/100 | train_loss=0.0047, train_acc=0.9991, val_loss=0.2400, val_acc=0.9733
# Эпоха 23/100 | train_loss=0.0048, train_acc=0.9989, val_loss=0.2460, val_acc=0.9767
# Эпоха 24/100 | train_loss=0.0049, train_acc=0.9989, val_loss=0.2449, val_acc=0.9750
# Эпоха 25/100 | train_loss=0.0044, train_acc=0.9988, val_loss=0.2426, val_acc=0.9742
# Эпоха 26/100 | train_loss=0.0043, train_acc=0.9989, val_loss=0.2440, val_acc=0.9717
# Эпоха 27/100 | train_loss=0.0042, train_acc=0.9995, val_loss=0.2585, val_acc=0.9733
# Эпоха 28/100 | train_loss=0.0052, train_acc=0.9988, val_loss=0.2553, val_acc=0.9758
# Эпоха 29/100 | train_loss=0.0049, train_acc=0.9986, val_loss=0.2453, val_acc=0.9758
# Эпоха 30/100 | train_loss=0.0041, train_acc=0.9991, val_loss=0.2464, val_acc=0.9742
# Эпоха 31/100 | train_loss=0.0039, train_acc=0.9993, val_loss=0.2569, val_acc=0.9733
# Эпоха 32/100 | train_loss=0.0038, train_acc=0.9989, val_loss=0.2548, val_acc=0.9733
# Эпоха 33/100 | train_loss=0.0047, train_acc=0.9984, val_loss=0.2638, val_acc=0.9750
# Эпоха 34/100 | train_loss=0.0041, train_acc=0.9989, val_loss=0.2579, val_acc=0.9725
# Эпоха 35/100 | train_loss=0.0041, train_acc=0.9989, val_loss=0.2596, val_acc=0.9742
# Эпоха 36/100 | train_loss=0.0046, train_acc=0.9988, val_loss=0.2707, val_acc=0.9733
# Эпоха 37/100 | train_loss=0.0053, train_acc=0.9986, val_loss=0.2578, val_acc=0.9733
# Эпоха 38/100 | train_loss=0.0046, train_acc=0.9989, val_loss=0.2562, val_acc=0.9775
# Эпоха 39/100 | train_loss=0.0043, train_acc=0.9989, val_loss=0.2723, val_acc=0.9742
# Эпоха 40/100 | train_loss=0.0046, train_acc=0.9991, val_loss=0.2760, val_acc=0.9725
# Эпоха 41/100 | train_loss=0.0057, train_acc=0.9989, val_loss=0.2729, val_acc=0.9750
# Эпоха 42/100 | train_loss=0.0057, train_acc=0.9988, val_loss=0.2658, val_acc=0.9725
# Эпоха 43/100 | train_loss=0.0052, train_acc=0.9984, val_loss=0.2735, val_acc=0.9742
# Эпоха 44/100 | train_loss=0.0075, train_acc=0.9970, val_loss=0.2816, val_acc=0.9708
# Эпоха 45/100 | train_loss=0.0184, train_acc=0.9943, val_loss=0.2935, val_acc=0.9683
# Эпоха 46/100 | train_loss=0.0552, train_acc=0.9866, val_loss=0.2787, val_acc=0.9675
# Эпоха 47/100 | train_loss=0.0474, train_acc=0.9859, val_loss=0.2296, val_acc=0.9692
# Эпоха 48/100 | train_loss=0.0277, train_acc=0.9904, val_loss=0.2185, val_acc=0.9708
# Эпоха 49/100 | train_loss=0.0276, train_acc=0.9907, val_loss=0.2457, val_acc=0.9717
# Эпоха 50/100 | train_loss=0.0234, train_acc=0.9929, val_loss=0.2330, val_acc=0.9700
# Эпоха 51/100 | train_loss=0.0230, train_acc=0.9939, val_loss=0.2677, val_acc=0.9758
# Эпоха 52/100 | train_loss=0.0234, train_acc=0.9920, val_loss=0.2270, val_acc=0.9725
# Эпоха 53/100 | train_loss=0.0212, train_acc=0.9923, val_loss=0.2647, val_acc=0.9667
# Эпоха 54/100 | train_loss=0.0177, train_acc=0.9948, val_loss=0.2467, val_acc=0.9750
# Эпоха 55/100 | train_loss=0.0113, train_acc=0.9968, val_loss=0.2441, val_acc=0.9733
# Эпоха 56/100 | train_loss=0.0080, train_acc=0.9979, val_loss=0.2314, val_acc=0.9742
# Эпоха 57/100 | train_loss=0.0063, train_acc=0.9986, val_loss=0.2322, val_acc=0.9742
# Эпоха 58/100 | train_loss=0.0052, train_acc=0.9988, val_loss=0.2285, val_acc=0.9725
# Эпоха 59/100 | train_loss=0.0047, train_acc=0.9989, val_loss=0.2468, val_acc=0.9742
# Эпоха 60/100 | train_loss=0.0052, train_acc=0.9989, val_loss=0.2382, val_acc=0.9742
# Эпоха 61/100 | train_loss=0.0046, train_acc=0.9986, val_loss=0.2435, val_acc=0.9733
# Эпоха 62/100 | train_loss=0.0034, train_acc=0.9993, val_loss=0.2478, val_acc=0.9750
# Эпоха 63/100 | train_loss=0.0034, train_acc=0.9993, val_loss=0.2533, val_acc=0.9717
# Эпоха 64/100 | train_loss=0.0036, train_acc=0.9993, val_loss=0.2534, val_acc=0.9717
# Эпоха 65/100 | train_loss=0.0043, train_acc=0.9989, val_loss=0.2480, val_acc=0.9742
# Эпоха 66/100 | train_loss=0.0037, train_acc=0.9989, val_loss=0.2526, val_acc=0.9733
# Эпоха 67/100 | train_loss=0.0034, train_acc=0.9993, val_loss=0.2621, val_acc=0.9733
# Эпоха 68/100 | train_loss=0.0030, train_acc=0.9993, val_loss=0.2614, val_acc=0.9733
# Эпоха 69/100 | train_loss=0.0029, train_acc=0.9991, val_loss=0.2558, val_acc=0.9733
# Эпоха 70/100 | train_loss=0.0037, train_acc=0.9993, val_loss=0.2708, val_acc=0.9742
# Эпоха 71/100 | train_loss=0.0031, train_acc=0.9991, val_loss=0.2579, val_acc=0.9742
# Эпоха 72/100 | train_loss=0.0028, train_acc=0.9993, val_loss=0.2687, val_acc=0.9742
# Эпоха 73/100 | train_loss=0.0028, train_acc=0.9993, val_loss=0.2617, val_acc=0.9742
# Эпоха 74/100 | train_loss=0.0025, train_acc=0.9993, val_loss=0.2684, val_acc=0.9758
# Эпоха 75/100 | train_loss=0.0030, train_acc=0.9993, val_loss=0.2573, val_acc=0.9733
# Эпоха 76/100 | train_loss=0.0036, train_acc=0.9993, val_loss=0.2680, val_acc=0.9725
# Эпоха 77/100 | train_loss=0.0029, train_acc=0.9991, val_loss=0.2607, val_acc=0.9742
# Эпоха 78/100 | train_loss=0.0027, train_acc=0.9991, val_loss=0.2700, val_acc=0.9733
# Эпоха 79/100 | train_loss=0.0035, train_acc=0.9991, val_loss=0.2633, val_acc=0.9742
# Эпоха 80/100 | train_loss=0.0055, train_acc=0.9989, val_loss=0.2642, val_acc=0.9725
# Эпоха 81/100 | train_loss=0.0043, train_acc=0.9989, val_loss=0.2675, val_acc=0.9758
# Эпоха 82/100 | train_loss=0.0031, train_acc=0.9993, val_loss=0.2799, val_acc=0.9733
# Эпоха 83/100 | train_loss=0.0030, train_acc=0.9993, val_loss=0.2728, val_acc=0.9758
# Эпоха 84/100 | train_loss=0.0028, train_acc=0.9991, val_loss=0.2664, val_acc=0.9750
# Эпоха 85/100 | train_loss=0.0026, train_acc=0.9991, val_loss=0.2839, val_acc=0.9750
# Эпоха 86/100 | train_loss=0.0024, train_acc=0.9993, val_loss=0.2807, val_acc=0.9733
# Эпоха 87/100 | train_loss=0.0024, train_acc=0.9993, val_loss=0.2755, val_acc=0.9717
# Эпоха 88/100 | train_loss=0.0034, train_acc=0.9993, val_loss=0.2863, val_acc=0.9758
# Эпоха 89/100 | train_loss=0.0043, train_acc=0.9993, val_loss=0.2828, val_acc=0.9767
# Эпоха 90/100 | train_loss=0.0036, train_acc=0.9993, val_loss=0.2784, val_acc=0.9733
# Эпоха 91/100 | train_loss=0.0029, train_acc=0.9993, val_loss=0.2766, val_acc=0.9758
# Эпоха 92/100 | train_loss=0.0032, train_acc=0.9989, val_loss=0.2793, val_acc=0.9742
# Эпоха 93/100 | train_loss=0.0025, train_acc=0.9993, val_loss=0.2934, val_acc=0.9758
# Эпоха 94/100 | train_loss=0.0027, train_acc=0.9993, val_loss=0.2788, val_acc=0.9767
# Эпоха 95/100 | train_loss=0.0030, train_acc=0.9991, val_loss=0.3029, val_acc=0.9750
# Эпоха 96/100 | train_loss=0.0029, train_acc=0.9991, val_loss=0.2875, val_acc=0.9742
# Эпоха 97/100 | train_loss=0.0026, train_acc=0.9993, val_loss=0.2857, val_acc=0.9742
# Эпоха 98/100 | train_loss=0.0029, train_acc=0.9993, val_loss=0.2923, val_acc=0.9742
# Эпоха 99/100 | train_loss=0.0027, train_acc=0.9991, val_loss=0.2861, val_acc=0.9775
# Эпоха 100/100 | train_loss=0.0020, train_acc=0.9995, val_loss=0.2932, val_acc=0.9758

# %%
epochs = np.arange(1, num_epochs + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs, history["train_loss"], label="train")
plt.plot(epochs, history["val_loss"], label="val")
plt.xlabel("Эпоха")
plt.ylabel("Loss")
plt.title("Функция потерь")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history["train_acc"], label="train")
plt.plot(epochs, history["val_acc"], label="val")
plt.xlabel("Эпоха")
plt.ylabel("Accuracy")
plt.title("Точность")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

print(f"Финальное качество: train_acc={history['train_acc'][-1]:.4f}, val_acc={history['val_acc'][-1]:.4f}")
# Out:
# Финальное качество: train_acc=0.9995, val_acc=0.9758

# %% [markdown]
# ### Ваш комментарий по кривым обучения
#
# Кратко опишите (6–8 предложений):
# - есть ли разрыв между train и val accuracy;
# - видно ли переобучение (train растёт, val падает или стагнирует);
# - насколько выбранные `num_epochs` и `learning_rate` кажутся вам удачными.
#
# Привязывайтесь к конкретным числам (например, точности на первой и последней эпохах).

# %%
training_comment = """ЗДЕСЬ ОПИШИТЕ, КАК ВЕЛИ СЕБЯ КРИВЫЕ НА ВАШИХ ЭКСПЕРИМЕНТАХ.
Укажите, есть ли признаки переобучения или недообучения, и что бы вы
сделали дальше (изменили число эпох, lr, архитектуру и т.п.).

Разрыв между val и train accuracy присутствует, но иногда большой, иногда нет. С использованием одних и тех же параметров получались разные ситуации, когда кривые были слишком шумные, и наоборот стабильные (например, на Adam lr=0.01)
Итоговая точность, где есть большой разрыв: train_acc=1.0000, val_acc=0.9683 (так в большинстве случаев)
Переобучение сильно заметно. Например, опять же на Adam lr=0.01 уже на 8 эпохе train рос, а val падал (всего было 25-50 эпох).
Для эксперимента попробовал добавить Dropout с вероятностью 0,5. Это улучшило ситуацию, разрыв стал меньше и кривые стали более стабильными, но val стал больше, чем train (не норма): train_acc=0.9641, val_acc=0.9742
Думаю, что выбранные num_epochs (25-50) и lr (0.01), потому что иногда они давали хороший результат. Но всё зависит от выбираемых моделью данных. На одних и тех же параметрах может получиться совершенно разный результат."""
print(training_comment)

# %% [markdown]
# ## 8. Оценка на тестовой выборке
#
# Теперь посмотрим, как модель работает на отложенном тестовом множестве, которое мы ещё ни разу не использовали при обучении и настройке гиперпараметров.

# %%
test_loss, test_acc = evaluate(model, test_loader, criterion, device)
print(f"Качество на тесте: loss={test_loss:.4f}, accuracy={test_acc:.4f}")
# Out:
# Качество на тесте: loss=0.2005, accuracy=0.9750

# %% [markdown]
# ### (Опционально) Примеры ошибок и дополнительные метрики
#
# Если хотите, можете:
# - собрать предсказания на test и посчитать матрицу ошибок (`confusion_matrix` из `sklearn`);
# - посмотреть, какие объекты модель чаще всего классифицирует неверно;
# - сравнить качество MLP с простой базовой моделью (например, логистической регрессией).
#
# Эта часть не обязательна, но полезна для более глубокого понимания.

# %% [markdown]
# ## 9. Итоговые выводы по вашей будущей работе
#
# В своей версии лабораторной вы будете использовать **свой** датасет и, возможно, другие настройки.
# Здесь сформулируйте общие выводы о том, что вам кажется важным при работе с табличными данными и MLP:
#
# - какие шаги предобработки оказались принципиальными (масштабирование, кодирование категорий и т.п.);
# - насколько чувствительной к этим шагам показалась вам модель;
# - где, на ваш взгляд, MLP может выигрывать у линейных моделей, а где — нет.
#
# Пишите как для будущего себя, который откроет этот ноутбук через полгода и захочет вспомнить, что здесь происходило.

# %%
final_reflection = """ЗДЕСЬ НАПИШИТЕ ИТОГОВЫЙ ТЕКСТ О ТОМ, ЧТО ВЫ ПОНЯЛИ
ПРО MLP НА ТАБЛИЧНЫХ ДАННЫХ: какие шаги кажутся критичными, какие параметры
вы бы в первую очередь тюнили, и когда вообще стоит брать нейросеть для
таких задач.

Скажу точно, что кодирование категорий стало одной из важной предобработкой данных, чтобы модель нормально их считывала.
Также важно правильно подобрать количество признаков при инициализации модели, чтобы их было не мало и не чрезмерно много.
Модель получилась очень чувствительная к числу эпох и lr. На одних и тех же гиперпараметрах она выдает разные результаты (как это возможно?).
В этой задаче MLP, скорее всего, не выигрывает у линейной модели. Может быть я что-то не так настроил, но результат меня совершенно не удовлетворил.
На датасете с картинками MLP отлично справляется, а с табличными данными лучше использовать иные методы решения."""
print(final_reflection)
